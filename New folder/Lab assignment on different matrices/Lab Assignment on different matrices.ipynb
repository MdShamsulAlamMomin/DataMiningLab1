# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-3ce2901c-2a02-4eda-8a28-4db961e8ff44" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3ce2901c-2a02-4eda-8a28-4db961e8ff44">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving MoviesData.csv to MoviesData.csv

# %%
import pandas as pd
df=pd.read_csv("MoviesData.csv")
print(df)
# Out:
#                                         Titles Rating  ...  Mystery  Documentary
# 0                              Treasure Planet     PG  ...        0            0
# 1                                About Schmidt      R  ...        0            0
# 2                                    Secretary      R  ...        0            0
# 3                                 Irreversible     NR  ...        0            0
# 4                                  Big Trouble   PG13  ...        0            0
# ..                                         ...    ...  ...      ...          ...
# 220  13 Hours: The Secret Soldiers of Benghazi      R  ...        0            0
# 221                                       Race   PG13  ...        0            0
# 222                           God's Not Dead 2     PG  ...        0            0
# 223                   The Purge: Election Year      R  ...        1            0
# 224                                   Warcraft   PG13  ...        0            0
#
# ...

# %%
print(df.head(10))
# Out:
#                             Titles Rating  ...  Mystery  Documentary
# 0                  Treasure Planet     PG  ...        0            0
# 1                    About Schmidt      R  ...        0            0
# 2                        Secretary      R  ...        0            0
# 3                     Irreversible     NR  ...        0            0
# 4                      Big Trouble   PG13  ...        0            0
# 5                    Resident Evil      R  ...        1            0
# 6                       Panic Room      R  ...        1            0
# 7                  Die Another Day   PG13  ...        1            0
# 8        Life or Something Like It   PG13  ...        0            0
# 9  Martin Lawrence Live: Runteldat      R  ...        0            0
#
# [10 rows x 19 columns]

# %%
print(df.tail(10))
# Out:
#                                         Titles Rating  ...  Mystery  Documentary
# 215                          The Young Messiah     PG  ...        0            0
# 216                               The 5th Wave   PG13  ...        1            0
# 217                               Jason Bourne   PG13  ...        0            0
# 218                                  Allegiant   PG13  ...        0            0
# 219            Pride and Prejudice and Zombies   PG13  ...        0            0
# 220  13 Hours: The Secret Soldiers of Benghazi      R  ...        0            0
# 221                                       Race   PG13  ...        0            0
# 222                           God's Not Dead 2     PG  ...        0            0
# 223                   The Purge: Election Year      R  ...        1            0
# 224                                   Warcraft   PG13  ...        0            0
#
# [10 rows x 19 columns]

# %%
print(df.dtypes)
# Out:
# Titles            object
# Rating            object
# RTCritic           int64
# RTFan              int64
# IMDb             float64
# Metacritic         int64
# BoxOffice          int64
# Year               int64
# Action             int64
# Animation          int64
# Family             int64
# Scifi              int64
# Comedy             int64
# Drama              int64
# International      int64
# Romance            int64
# Horror             int64
# Mystery            int64
# Documentary        int64
# dtype: object

# %%
print(df.columns)
# Out:
# Index(['Titles', 'Rating', 'RTCritic', 'RTFan', 'IMDb', 'Metacritic',
#        'BoxOffice', 'Year', 'Action', 'Animation', 'Family', 'Scifi', 'Comedy',
#        'Drama', 'International', 'Romance', 'Horror', 'Mystery',
#        'Documentary'],
#       dtype='object')

# %%
df1=df.drop(["BoxOffice", "Year", "Action"],axis=1)
print(df1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-ea8c20de58b5> in <module>()
# ----> 1 df1=df.drop(["BoxOffice", "Year", "Action"],axis=0)
#       2 print(df1)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4172             level=level,
#    4173             inplace=inplace,
# -> 4174             errors=errors,
#    4175         )
#    4176
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3887         for axis, labels in axes.items():
#    3888             if labels is not None:
# -> 3889                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3890
#    3891         if inplace:
#
# ...
